# %%
import os
from datetime import datetime
import pandas as pd


BASE_URL = "https://www.zse.co.zw/price-sheet/"


def fetch_data_from_url(url):
    """
    Fetch the market prices from the Zimbabwe Stock Exchange Website
    """
    try:
        response = pd.read_html(url, skiprows=1)

    except Exception as e:
        pass

    dataframe = response[0][4:]
    # The response has 8 columns but only concerned with few
    dataframe.columns = [
        "Name",
        "None",
        "None",
        "None",
        "None",
        "Opening_Price",
        "Closing_Price",
        "Volume_Traded",
    ]
    # Lets filter the columns we are concerned with
    df_trades = dataframe[["Name", "Opening_Price", "Closing_Price", "Volume_Traded"]]

    # Drop all the columns with no data or missing all data
    dataframe = df_trades.dropna(how="all").set_index('Name')
    return dataframe


def current_date():
    """
    Generate the current date for use in saving the price sheet
    """
    now = datetime.now()
    current_date = now.strftime("%m-%d-%Y")
    return current_date


def check_or_create_directory(dataframe, current_date):
    """
    Create or save in the folder with other files
    """
    os.makedirs("csv-daily-pricesheets", exist_ok=True)
    # Save the data into both the CSV and Excel folders
    dataframe.to_csv(f"csv-daily-pricesheets/{current_date}.csv")
    dataframe.to_csv(f"xls-daily-price-sheets/{current_date}.xlsx")


dataframe = fetch_data_from_url(BASE_URL)
dataframe
# Out:
#                                                     Opening_Price  \
# Name
# Afdis Distillers Limited                                 330.0000
# African Sun Limited                                       17.0233
# Amalgamated Regional Trading (Art) Holdings Lim...        17.0000
# Ariston Holdings Limited                                   2.5000
# Axia Corporation Limited                                  76.0000
# Bridgefort Capital Limited                                19.0000
# Bridgefort Capital Limited Class B                        26.0000
# British American Tobacco Zimbabwe Limited               2450.0000
# Cafca Limited                                            235.5000
# Cbz Holdings Limited                                     132.0162
# Cfi Holdings Limited                                     370.0000
# Dairibord Holdings Limited                                30.0000
# Delta Corporation Limited                                220.9952
# Ecocash Holdings Zimbabwe Limited                         49.0000
# Econet Wireless Zimbabwe Limited                         159.7215
# Edgars Stores Limited                                      6.0003
# Fbc Holdings Limited                                      60.6250
# Fidelity Life Assurance Limited                           22.0000
# First Capital Bank Limited                                 8.6143
# First Mutual Holdings Limited                             18.0000
# First Mutual Properties Limited                            9.0000
# General Beltings Holdings Limited                          1.5910
# Getbucks Microfinance Bank Limited                        17.0000
# Hippo Valley Estates Limited                             246.9500
# Innscor Africa Limited                                   289.9113
# Lafarge Cement Zimbabwe Limited                          120.0000
# Mashonaland Holdings Limited                               4.9959
# Masimba Holdings Limited                                  50.0000
# Meikles Limited                                          109.0000
# Nampak Zimbabwe Limited                                   12.0000
# National Foods Holdings Limited                         1750.0000
# National Tyre Services Limited                            11.7500
# Nmbz Holdings Limited                                     20.0000
# Ok Zimbabwe Limited                                       30.0000
# Proplastics Limited                                       25.0000
# Rainbow Tourism Group Limited                              9.0000
# Riozim Limited                                            93.5238
# Seed Co Limited                                           90.0000
# Simbisa Brands Limited                                   190.1396
# Starafricacorporation Limited                              1.5876
# Tanganda Tea Company Limited                             138.5000
# Truworths Limited                                          2.0394
# Tsl Limited                                               85.0000
# Turnall Holdings Limited                                   4.5700
# Unifreight Africa Limited                                 50.0000
# Willdale Limited                                           2.6100
# Zb Financial Holdings Limited                            122.0000
# Zeco Holdings Limited                                      0.0288
# Zimbabwe Newspapers (1980) Limited                         5.0000
# Zimplow Holdings Limited                                  19.0000
# Zimre Holdings Limited                                     3.6186
#
#                                                     Closing_Price  \
# Name
# Afdis Distillers Limited                                 330.0000
# African Sun Limited                                       16.5000
# Amalgamated Regional Trading (Art) Holdings Lim...        17.0000
# Ariston Holdings Limited                                   2.5000
# Axia Corporation Limited                                  74.0625
# Bridgefort Capital Limited                                19.0000
# Bridgefort Capital Limited Class B                        26.0000
# British American Tobacco Zimbabwe Limited               2450.0000
# Cafca Limited                                            235.5000
